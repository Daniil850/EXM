# %%
import requests
from bs4 import BeautifulSoup

# %%
page = requests.get('https://habr.com/ru/top/monthly/')

# %%
page.status_code
# Out:
# 200

# %%
page.text
# Out:
# '<!DOCTYPE html>\n<html lang="ru" data-vue-meta="%7B%22lang%22:%7B%22ssr%22:%22ru%22%7D%7D">\n<head >\n  <meta charset="UTF-8">\n  <meta name="viewport" content="width=device-width,initial-scale=1.0,viewport-fit=cover">\n  <meta name="referrer" content="unsafe-url">\n  <title>Лучшие публикации за  месяц  / Хабр</title>\n  <style>\n    /* cyrillic-ext */\n    @font-face {\n      font-family: \'Fira Sans\';\n      font-style: normal;\n      font-weight: 500;\n      font-display: swap;\n      src: url(https://fonts.gstatic.com/s/firasans/v11/va9B4kDNxMZdWfMOD5VnZKveSxf6TF0.woff2) format(\'woff2\');\n      unicode-range: U+0460-052F, U+1C80-1C88, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F;\n    }\n\n    /* cyrillic */\n    @font-face {\n      font-family: \'Fira Sans\';\n      font-style: normal;\n      font-weight: 500;\n      font-display: swap;\n      src: url(https://fonts.gstatic.com/s/firasans/v11/va9B4kDNxMZdWfMOD5VnZKveQhf6TF0.woff2) format(\'woff2\');\n      unicode-range: U+
# ...

# %%
soup = BeautifulSoup(page.text,'html.parser')

# %%
posts = soup.find_all('article', class_="tm-articles-list__item")

# %%
len(posts)
# Out:
# 20

# %%
posts[0]
# Out:
# <article class="tm-articles-list__item" data-navigatable="" id="594633" tabindex="0"><div class="tm-article-snippet"><div class="tm-article-snippet__meta-container"><div class="tm-article-snippet__meta"><span class="tm-user-info tm-article-snippet__author"><a class="tm-user-info__userpic" href="/ru/users/alatobol/" title="alatobol"><div class="tm-entity-image"><img alt="" class="tm-entity-image__pic" height="24" src="//habrastorage.org/r/w32/getpro/habr/avatars/fa6/fdd/17b/fa6fdd17b91b00edae7f7e1a78da0b67.jpg" width="24"/></div></a> <span class="tm-user-info__user"><a class="tm-user-info__username" href="/ru/users/alatobol/">
#       alatobol
# ...

# %%
post_0_header = soup.find('h2')
post_0_header
# Out:
# <h2 class="tm-article-snippet__title tm-article-snippet__title_h2"><a class="tm-article-snippet__title-link" data-article-link="" href="/ru/company/vk/blog/594633/"><span>Как мы отказались от JPEG, JSON, TCP и ускорили ВКонтакте в два раза</span></a></h2>

# %%
post_0_title = post_0_header.find('span').string
post_0_title
# Out:
# 'Как мы отказались от JPEG, JSON, TCP и ускорили ВКонтакте в два раза'

# %%
titles = []
for post in posts:
        post_header = post.find('h2')
        title =  post_header.find('span').string
        titles.append(title)
titles
# Out:
# ['Как мы отказались от JPEG, JSON, TCP и ускорили ВКонтакте в два раза',
#  'Современное пиратство глазами моряка',
#  'Питон против Безумного Макса, или как я посты на Хабре замораживал',
#  'Современное пиратство глазами моряка. Наёмники',
#  'Как Google подсунул нам котлеты и чуть не погубил проект. Почти юмористическая и почти детективная история одной ошибки',
#  'БабаГрам: Телеграм для бабушки',
#  'Что делать, когда преследует бывший… работодатель?',
#  'Сертификат COVID-19 не найден: Почему на самом деле перестали работать QR-коды о вакцинации',
#  'NFT — бесполезная технология',
#  'Оффер в Вооруженные Силы РФ, от которого нельзя отказаться',
#  'К нам приехал моноблок на «Байкале» для офиса — «Ну а чего вы ждали?»',
#  'Почему Starlink от Маска — это скам',
#  'Антибиотикорезистентность: ура, мы дождались! Считайте, что вышел анонс следующей пандемии',
#  'Препарируем дельфина: что внутри у Flipper Zero',
#  'СТРАННЫЕ Люди. Как западная цивилизация вырвалась вперед?',
# ...

# %%
for ad in posts:
        h = soup.find_all('span').string
        print(h)
# Out:
# 'Как мы отказались от JPEG, JSON, TCP и ускорили ВКонтакте в два раза'
